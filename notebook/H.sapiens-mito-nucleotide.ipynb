# %%
# Install the BioPython package
# !pip install biopython

# Import necessary libraries
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt

# Make plots appear in notebook
# %matplotlib inline
# Out:
# Requirement already satisfied: biopython in /opt/anaconda3/lib/python3.13/site-packages (1.86)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from biopython) (2.3.5)

# %%
# Path to FASTA file
fasta_path = "/data/human-mito.fasta"

# Parse FASTA file
record = SeqIO.read(fasta_path, "fasta")

# Extract sequence
sequence = str(record.seq)

print("Sequence loaded!")
print("Sequence length:", len(sequence))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 fasta_path = "/data/ecoli_genome.fasta"
#       4 # Parse FASTA file
# ----> 5 record = SeqIO.read(fasta_path, "fasta")
#       7 # Extract sequence
#       8 sequence = str(record.seq)
#
# File /opt/anaconda3/lib/python3.13/site-packages/Bio/SeqIO/__init__.py:719, in read(handle, format, alphabet)
#     679 def read(handle, format, alphabet=None):
#     680     """Turn a sequence file into a single SeqRecord.
#     681
#     682     Arguments:
#    (...)    717     to read multiple records from the handle.
#     718     """
# --> 719     with parse(handle, format, alphabet) as records:
#     720         try:
#     721             record = next(records)
#
# File /opt/anaconda3/lib/python3.13/site-packages/Bio/SeqIO/__init__.py:674, in parse(handle, format, alphabet)
#     672 iterator_generator = _FormatToIterator.get(format)
#     673 if iterator_generator:
# --> 674     return iterator_generator(handle)
#     676 raise ValueError(f"Unknown format '{format}'")
#
# File /opt/anaconda3/lib/python3.13/site-packages/Bio/SeqIO/FastaIO.py:196, in FastaIterator.__init__(self, source, alphabet)
#     194 if alphabet is not None:
#     195     raise ValueError("The alphabet argument is no longer supported")
# --> 196 super().__init__(source, fmt="Fasta")
#     197 line = self.stream.readline()
#     198 if not line:
#
# File /opt/anaconda3/lib/python3.13/site-packages/Bio/SeqIO/Interfaces.py:82, in SequenceIterator.__init__(self, source, alphabet, fmt)
#      80 if isinstance(source, _PathLikeTypes):
#      81     mode = modes[0]
# ---> 82     self.stream = open(source, "r" + mode)
#      83 else:
#      84     value = source.read(0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/ecoli_genome.fasta'
